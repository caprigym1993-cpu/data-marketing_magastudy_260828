# %%
# 기초 함수 정의하기
#시중 교보문고 깃 깃허브 
#git comit & push 관리 ai (간단한 에러는 거의 나오지 않음 ) 
def addfnc(num01, num02) :
    return num01 + num02
    print(num01 + num02)

# %%
sumtotal = addfnc(1,2)

# %%
print(sumtotal)
# Out:
# 3
