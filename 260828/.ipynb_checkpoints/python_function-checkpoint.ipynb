# %%
#함수 : 인풋 ,프로세스 , 아웃풋 
#지역변수= 로컬 베리어블 =지역 방송
#전역변수 = 글로벌 베리어블 =전국구 방송
#그동안 우리가 일반적으로 사용해왔던 변수들은 전역 변수

# %%
#인풋 아웃풋 존재하지않음 함수 
def func1() :
    print("Hello")

# %%
func1()
# Out:
# Hello

# %%
#인풋 존재 아웃풋 없엄 
def func2(params) :
    print(params + "님 반갑습니다")
     print(f"{params}님 반갑습니다")
# Out:
#   Cell In[6], line 4
#     print(f"{params}님 반갑습니다")
#     ^
# IndentationError: unexpected indent

# %%
func2("dlwl")
# Out:
# dlwl님 반갑습니다

# %%
#인풋존재 아웃풋 존재 
def func3(data1, data2) : 
    return data1 + data2

# %%
sumtotal = func3(5, 5)
print(sumtotal)
# Out:
# 10

# %%
def sum01(a, b) :
    result = a+ b
    return result

# %%
sum01(3, 5)
def mul_return(a) :
b  =a * 2
return a, b
# Out:
#   Cell In[14], line 3
#     b  =a * 2
#     ^
# IndentationError: expected an indented block after function definition on line 2

# %%
sum01(3, 5)

def mul_return(a):
    b = a * 2
    return a, b

# %%
mul_return(3)
# Out:
# (3, 6)

# %%
#변수 
#

# %%
list01 = [1, 2, 3]
lost02 = list()
tuple01 = (1, 2, 3)

# %%
type(tuple01)
# Out:
# tuple

# %%
tuple01[2]
# Out:
# 3

# %%
tuple01{1}

# %%
data1 = (1, 2, 3)
data2 = (4, 5, 6)

result =
