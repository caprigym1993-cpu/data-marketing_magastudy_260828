# %% [markdown]
# #  오늘의 학습 목표
# ## 1. 파이썬 기초 문법
# - 변수 선언 및 할당
# - 자료형
# - 자료구조
# ---
# ## 2. 파이썬 조건문
# - if문
# - if/else문
# -

# %% [markdown]
# ### 주석이란 ?
# - => 주석 ( 실제 실행되지 않는 부연 설명)
# - cell +셀
# - 1개의 셀 안에서 파이썬 코드를 입력 및 실행
# - a 는 당해년도 값을 담기위한 변수
# - 변수를 선언 할 때에는 "직관적"& "명시적" 작명 원칙
# - "year"라는 변수 선언후 2026이라는 숫자 값을 할당
# - 좌항(변수= valiable) vs 우항 (변수의 담을 값 =valus)

# %%
a = 2026
year = 2026

# %%
# python -> 영어로된 단어 이름( )> 함수 = funchion =기능
# 프린트라는 함수는 내가 만든것 x , 파이썬 언어 창시자가 만들어놓음 그걸 우리가 가져다 사용함 
#내장(이미 만들어서 내장 되어 있었던) 함수 
#프로그래밍 언어 문법 

print(year) # 프린트라는 함수는 소괄호 안에 입력된 값을 셀 결과 값으로 출력해주는 기능
# Out:
# 2026

# %%
text = "hello world"

# %%
#왜 2026을넣을때는 따움표 없어도 가능
#헬로우 월드는 따움표 가 왜 필요해 ?

#형 (태) =type

# %%
# 변수 선언 , 할당 
#변수 할당 가능한 형(태)

# %%
#정수 :integer // 3,6,9
#실수 :float // 3.1,3.2.3.3 .....5,9,6,0
#문자열:string// "안녕하세요" = '안녕하세요'  (x)char ' 안' str "안녕"
#논리형:boolean // true (참) , false(거짓)

# %%
# 변수에 입력 가능한 "기본형 "타입 
int01 = 7 # 인트 01 이라는 변수 선언, 해당 변수안에 7이라는 정수 할당 
float01 = 6.4 
str01 = "hello"
bool01 = True

# %%
#Type( : 함수= 기능  : 해당 변수 안에 입력되어있는 값이 어떤 형태인지 알려주는 기능 
#Print () :값을 출력하게 도와주는 기능 
#알트 +씹프트 + 다운 키 : 셀안에 입력된 문장 복사 
#print () : 해당 셀안에 몇번째 행에 있던지 결과를 출력해줌 
#만약에 셀안에 프린트 () 함수를 사용하지 않아도 하지만 마지막 번째 행의 결과는 자동으로 출력 

print (type(int01), type(float01), type(str01), type(bool01))

#매개 변수 (argument) ,인자값 , 인수 (인강, 책) 
#박세진 ,선생님 ,강사님
#남편 
#아빠
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %%
#프로그래밍 언어 역사 
#1. 절차지향 프로그래밍 언어 (c언어 : 대부분의 프로그래밍 언어 조상격 )
#절차지향 > 컴퓨터 이해하기 펴하도록> 모든 실행값 문법의 절차에 반드시 맞춰서 작성 
#2. 객체지향 프로그래밍 언어 (python , javascript , java) -> class -> instance
# 절차 지향의 좋은점 수용 / 융통성이 없는 문법 배제 
# 절차 -> 클래스 (class -> 붕어빵틀)
#반죽// 모양 틀 기계 //성형x // 무한한

# %%
int02 = 10 
int03 = '10'

# %%
print(type(int02), type(int03))
# Out:
# <class 'int'> <class 'str'>

# %%
# 파이썬 . 크롤링( 무신사) . 베스트 셀러 상품 탑3 좋아요 및 리뷰수 평균 값 계산 (카테고리별)

# 20. 60 개  상품 좋아요 ,리뷰수. 평균 2,457 ,. 크롤링 .정수 값x . (문자 +문자+문자) / 3

# %%
# 정수 = 숫자 
# 사용할수 있는 속성 , 매서드 , 연산자 상이함 =다르다 
#속성 (변수안에 잇는 값의 정보를 추출 할 때 사용할수 있는 요소 =something = element)
#메서드 ( 변수 안에 있는 값을 활용해서 기능 구현 =method

# %%
# 20) 정수라는 형태의 값이 변수에 할당 된다면 , 가장 많이 사용하는 문법 . 연산자 
# 사칙연산 (+,-*,/) +@ ( 나머지 연산 ,제곱근 , 몫 )
intA = 7 
intB = 3 
print(intA + intB)
print(intA - intB)
print(intA * intB)
print(intA / intB)
print(3 + 7 )
# Out:
# 10
# 4
# 21
# 2.3333333333333335
# 10

# %%
print(intA // intB) #7/3 = 몫
print(intA % intB)# 7%3= 나머지 . 값이 짝수 ,홀수 인지 
print(intA ** intB) # 7^3
# Out:
# 2
# 1
# 343

# %%
# 플로트 > 인트 타입에 사용가능한 모든 연산자 다 사용가능!

# %%
# BOOLEAN >TRUE , FALSE > 명제 >조건문 , 반복문 
print(intA > intB)# 비교연산자 
print(intA < intB)
print(intA == intB) #변수선언, 할당 -> = ; 할당
print(intA != intB) = #부정연산자 =not
print(intA >= intB)
print(intA <= intB)
# Out:
# True
# False
# False
# True
# True
# False

# %%
# 내장 함수 
#print()
#type ()
#input()

# %%
name =input("what is your name?")
#print("hi ", name) #프린트()-> 문자 , 변수를 , 구분자로 구분해서 사용해야 한다 ! 유추 
print(f"hi  {name}")
#f-amestring 문법 + formatted string = 문자열 + 변수 구분하지 않고 한번에 사용할수 있도록 해주는것
# Out:
# what is your name? lee
# hi  lee

# %%
# 공부 방법
#1) 문법을 정석대로 학습
#2 실전 문제를 해결해 가면서 부분적으로 문법을 학습 
# 에이 문제를+> 에이-1 
#비 문제해결 +> 비 -1 
# 프로그래밍 언어 연결성 : 에이-1 & 비 -1 : 굳이 나눠서 분리 하지 않아도  c문법

# %%
intC = 100
strD = "nike"
strF = "200"
intE =200
print(intC + int(strF))
# 형변환
# Out:
# 300

# %% [markdown]
# 1. 형변환 함수
# - int(): 정수형 태로 변환
# - float() : 실수형태로 변환
# - str() : 문자열로 변환
# - bool () : 논리형으로 변환
# -

# %%
test01 = float(7) 
test02 = str(7) 
test03 = bool(0)
test04 = bool(7)
print( test01 , test02)
# Out:
# 7.0 7
